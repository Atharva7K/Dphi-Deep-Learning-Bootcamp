# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt

# %%
import pandas as pd

startup_data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/startupdata/training_set_label.csv" )
startup_data.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0        1005         CA  42.358880  ...            1.0000         0  acquired
# 1         204         CA  37.238916  ...            4.7500         1  acquired
# 2        1001         CA  32.901049  ...            4.0000         1  acquired
# 3         738         CA  37.320309  ...            3.3333         1  acquired
# 4        1002         CA  37.779281  ...            1.0000         1    closed
#
# [5 rows x 48 columns]

# %%
startup_data.founded_at = pd.to_datetime(startup_data.founded_at)
startup_data.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0        1005         CA  42.358880  ...            1.0000         0  acquired
# 1         204         CA  37.238916  ...            4.7500         1  acquired
# 2        1001         CA  32.901049  ...            4.0000         1  acquired
# 3         738         CA  37.320309  ...            3.3333         1  acquired
# 4        1002         CA  37.779281  ...            1.0000         1    closed
#
# [5 rows x 48 columns]

# %%
startup_data.loc[~(startup_data.closed_at.isnull()), 'closed_at'] = pd.to_datetime(startup_data.loc[startup_data.closed_at.notna(), 'closed_at'])

# %%
startup_data.head(20)
# Out:
#     Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0         1005         CA  42.358880  ...            1.0000         0  acquired
# 1          204         CA  37.238916  ...            4.7500         1  acquired
# 2         1001         CA  32.901049  ...            4.0000         1  acquired
# 3          738         CA  37.320309  ...            3.3333         1  acquired
# 4         1002         CA  37.779281  ...            1.0000         1    closed
# 5          379         CA  37.406914  ...            3.0000         1    closed
# 6          195         CA  37.391559  ...            1.6667         1  acquired
# 7          875         CA  38.057107  ...            3.5000         1  acquired
# 8           16         MA  42.712207  ...            4.0000         1  acquired
# 9          846         CA  37.427235  ...            1.0000         1  acquired
# 10         685         CA  37.442988  ...            1.0000         1  acquired
# ...

# %%
startup_data.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0        1005         CA  42.358880  ...            1.0000         0  acquired
# 1         204         CA  37.238916  ...            4.7500         1  acquired
# 2        1001         CA  32.901049  ...            4.0000         1  acquired
# 3         738         CA  37.320309  ...            3.3333         1  acquired
# 4        1002         CA  37.779281  ...            1.0000         1    closed
#
# [5 rows x 48 columns]

# %%
current_date = dt.datetime(2020, 10, 4)

startup_data.closed_at = startup_data.closed_at.fillna(current_date)

# %%
startup_data.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0        1005         CA  42.358880  ...            1.0000         0  acquired
# 1         204         CA  37.238916  ...            4.7500         1  acquired
# 2        1001         CA  32.901049  ...            4.0000         1  acquired
# 3         738         CA  37.320309  ...            3.3333         1  acquired
# 4        1002         CA  37.779281  ...            1.0000         1    closed
#
# [5 rows x 48 columns]

# %%
startup_data['Age'] = startup_data.closed_at - startup_data.founded_at

# %%
startup_data['Age'] = startup_data['Age'].map(lambda x: x.days)

# %%
startup_data = startup_data.loc[~(startup_data.Age < 0)]

# %%
startup_data.shape
# Out:
# (920, 49)

# %%
startup_data.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  is_top500    status   Age
# 0        1005         CA  42.358880  ...          0  acquired  5025
# 1         204         CA  37.238916  ...          1  acquired  7582
# 2        1001         CA  32.901049  ...          1  acquired  4218
# 3         738         CA  37.320309  ...          1  acquired  6851
# 4        1002         CA  37.779281  ...          1    closed   792
#
# [5 rows x 49 columns]

# %%
startup_data.isnull().sum()
# Out:
# Unnamed: 0                    0
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# id                            0
# city                          0
# Unnamed: 6                  491
# name                          0
# founded_at                    0
# closed_at                     0
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    151
# age_last_milestone_year     151
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# state_code.1                  1
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# ...

# %%
startup_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 920 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                920 non-null    int64
#  1   state_code                920 non-null    object
#  2   latitude                  920 non-null    float64
#  3   longitude                 920 non-null    float64
#  4   zip_code                  920 non-null    object
#  5   id                        920 non-null    object
#  6   city                      920 non-null    object
#  7   Unnamed: 6                429 non-null    object
#  8   name                      920 non-null    object
#  9   founded_at                920 non-null    datetime64[ns]
#  10  closed_at                 920 non-null    datetime64[ns]
#  11  first_funding_at          920 non-null    object
#  12  last_funding_at           920 non-null    object
# ...

# %%
startup_data.isnull().sum()
# Out:
# Unnamed: 0                    0
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# id                            0
# city                          0
# Unnamed: 6                  491
# name                          0
# founded_at                    0
# closed_at                     0
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    151
# age_last_milestone_year     151
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# state_code.1                  1
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# ...

# %%
columns_drop = ['zip_code', 'id', 'name', 'object_id', 'category_code','state_code.1', 'latitude', 'longitude' ]
data1 = startup_data.drop(columns_drop, axis = 'columns')

# %%
data1.drop('Unnamed: 6', axis = 'columns', inplace = True)

# %%
data1.drop('Unnamed: 0', axis = 'columns', inplace = True)

# %%
data1.shape
# Out:
# (920, 39)

# %%
data1.isnull().sum()
# Out:
# state_code                    0
# city                          0
# founded_at                    0
# closed_at                     0
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    151
# age_last_milestone_year     151
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# is_gamesvideo                 0
# is_ecommerce                  0
# is_biotech                    0
# is_consulting                 0
# is_othercategory              0
# ...

# %%
data1.loc[(data1.age_first_milestone_year.isnull()) & (data1.closed_at.notnull()), :]
# Out:
#     state_code           city founded_at  ... is_top500    status   Age
# 12          KY     Louisville 2004-01-01  ...         0    closed  3039
# 15          VA         Vienna 1999-01-01  ...         0    closed  4104
# 24          CO        Boulder 2007-05-01  ...         1    closed  1007
# 32          NC         Durham 2006-10-01  ...         1    closed  1965
# 34          PA     Pittsburgh 2009-06-01  ...         0    closed  1091
# ..         ...            ...        ...  ...       ...       ...   ...
# 885         CO           Avon 2005-01-01  ...         1    closed  1889
# 903         CA    Santa Clara 2002-01-01  ...         1  acquired  6851
# 904         TX        Houston 2003-01-01  ...         1    closed  2298
# 906         CA    Santa Clara 2000-01-01  ...         1  acquired  7582
# 912         CA  San Francisco 2005-04-22  ...         1  acquired  5644
#
# [151 rows x 39 columns]

# %%
data1.drop(['age_first_milestone_year', 'age_last_milestone_year'], axis = 'columns', inplace = True)

# %%
data1.drop(['founded_at', 'closed_at'], axis = 'columns', inplace = True)

# %%
sns.countplot(data1.status)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.kdeplot(data1.Age, hue = data1.status)

# %%
data1.loc[data1.Age <0, ]
# Out:
# Empty DataFrame
# Columns: [state_code, city, first_funding_at, last_funding_at, age_first_funding_year, age_last_funding_year, relationships, funding_rounds, funding_total_usd, milestones, is_CA, is_NY, is_MA, is_TX, is_otherstate, is_software, is_web, is_mobile, is_enterprise, is_advertising, is_gamesvideo, is_ecommerce, is_biotech, is_consulting, is_othercategory, has_VC, has_angel, has_roundA, has_roundB, has_roundC, has_roundD, avg_participants, is_top500, status, Age]
# Index: []

# %%
plt.xticks(rotation = 90)
sns.countplot(data1.state_code)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x = data1.status, y = data1.funding_total_usd, hue = data1.funding_rounds)

# %%
data1.city.nunique()
# Out:
# 221

# %%
city_map = {'San Francisco':1,'New York':2,'Mountain View':3, 'Palo Alto':4, 'Santa Clara':5}
data1.city = data1.city.map(city_map)
#data1.loc[data1.city.isnull(), 'city'] = 6

# %%
data1.city = data1.city.fillna(value = 6)

# %%
data1.isnull().sum()
# Out:
# state_code                0
# city                      0
# first_funding_at          0
# last_funding_at           0
# age_first_funding_year    0
# age_last_funding_year     0
# relationships             0
# funding_rounds            0
# funding_total_usd         0
# milestones                0
# is_CA                     0
# is_NY                     0
# is_MA                     0
# is_TX                     0
# is_otherstate             0
# is_software               0
# is_web                    0
# is_mobile                 0
# is_enterprise             0
# is_advertising            0
# is_gamesvideo             0
# is_ecommerce              0
# is_biotech                0
# is_consulting             0
# is_othercategory          0
# has_VC                    0
# has_angel                 0
# has_roundA                0
# has_roundB                0
# has_roundC                0
# has_roundD                0
# avg_participants          0
# is_top500                 0
# ...

# %%
data1.drop(['state_code','first_funding_at', 'last_funding_at'], axis = 'columns', inplace = True)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 920 entries, 0 to 922
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    920 non-null    float64
#  1   age_first_funding_year  920 non-null    float64
#  2   age_last_funding_year   920 non-null    float64
#  3   relationships           920 non-null    int64
#  4   funding_rounds          920 non-null    int64
#  5   funding_total_usd       920 non-null    int64
#  6   milestones              920 non-null    int64
#  7   is_CA                   920 non-null    int64
#  8   is_NY                   920 non-null    int64
#  9   is_MA                   920 non-null    int64
#  10  is_TX                   920 non-null    int64
#  11  is_otherstate           920 non-null    int64
#  12  is_software             920 non-null    int64
#  13  is_web                  920 non-null    int64
# ...

# %%
ohe_city = pd.get_dummies(data1.city)

# %%
data1.merge(ohe_city, right_index=True, left_index=True)
# Out:
#      city  age_first_funding_year  age_last_funding_year  ...  4.0  5.0  6.0
# 0     6.0                  2.2493                 3.0027  ...    0    0    1
# 1     6.0                  5.1260                 9.9973  ...    0    0    1
# 2     6.0                  1.0329                 1.0329  ...    0    0    1
# 3     6.0                  3.1315                 5.3151  ...    0    0    1
# 4     1.0                  0.0000                 1.6685  ...    0    0    0
# ..    ...                     ...                    ...  ...  ...  ...  ...
# 918   1.0                  0.5178                 0.5178  ...    0    0    0
# 919   6.0                  7.2521                 9.2274  ...    0    0    1
# 920   6.0                  8.4959                 8.4959  ...    0    0    1
# 921   1.0                  0.7589                 2.8329  ...    0    0    0
# 922   5.0                  3.1205                 3.1205  ...    0    1    0
#
# [920 rows x 38 columns]

# %%
data1.drop('city', inplace = True, axis = 'columns')

# %%
mean = data1.funding_total_usd.mean()
std = data1.funding_total_usd.std()
range = mean + std*3
data1 = data1.loc[~(data1.funding_total_usd>range), :]

# %%
data1.shape
# Out:
# (919, 31)

# %%
mean = data1.avg_participants.mean()
std = data1.avg_participants.std()
range = mean + 3*std


data1.loc[data1.avg_participants > range, :].shape
# Out:
# (19, 31)

# %%
x = data1.drop('status', axis = 'columns')

# %%
sns.kdeplot(data1.Age, hue = data1.status)

# %%
x.head()
# Out:
#    age_first_funding_year  age_last_funding_year  ...  is_top500   Age
# 0                  2.2493                 3.0027  ...          0  5025
# 1                  5.1260                 9.9973  ...          1  7582
# 2                  1.0329                 1.0329  ...          1  4218
# 3                  3.1315                 5.3151  ...          1  6851
# 4                  0.0000                 1.6685  ...          1   792
#
# [5 rows x 30 columns]

# %%
status_map = {'acquired':1, 'closed':0}
y = data1.status.map(status_map).values

# %%
y.shape
# Out:
# (919,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 42)

# %%
y_train.shape
# Out:
# (643,)

# %%
y_train[:5]
# Out:
# array([0, 1, 0, 1, 0])

# %%
x_train.shape
# Out:
# (643, 30)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)

# %%
scaler1 = MinMaxScaler()
x_test_scaled = scaler.fit_transform(x_test)

# %%
x_train_scaled.shape
# Out:
# (643, 30)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(x_test_scaled)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 91,  12],
#        [ 37, 136]])

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79       103
#            1       0.92      0.79      0.85       173
#
#     accuracy                           0.82       276
#    macro avg       0.81      0.83      0.82       276
# weighted avg       0.84      0.82      0.83       276

# %%
from sklearn.svm import SVC
classifier_svc = SVC(kernel = 'rbf')
classifier_svc.fit(x_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svc_pred = classifier_svc.predict(x_test_scaled)
report = classification_report(y_test, svc_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92       103
#            1       0.92      1.00      0.96       173
#
#     accuracy                           0.94       276
#    macro avg       0.96      0.92      0.94       276
# weighted avg       0.95      0.94      0.94       276

# %%
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid.fit(x_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.651, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.659, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.659, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.656, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.656, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.651, total=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# 0.9828972868217054

# %%
grid.best_estimator_

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(x_train_scaled.shape[1],)))  

#model.add(Dense(32, activation='relu'))
#model.add(Dense(16, activation='relu'))
#model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compiling the model
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(0.001)  # Here, we have set our learning rate as 0.001
model.compile(loss='binary_crossentropy', optimizer= optimizer , metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 32)                992
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# ...
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaled, y_train, validation_split=0.1, epochs=100, batch_size=10, verbose=1)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.6246 - val_loss: 0.6308 - val_accuracy: 0.6769
# Epoch 2/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5904 - accuracy: 0.6903 - val_loss: 0.6137 - val_accuracy: 0.6615
# Epoch 3/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5673 - accuracy: 0.7093 - val_loss: 0.5963 - val_accuracy: 0.7077
# Epoch 4/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5460 - accuracy: 0.7301 - val_loss: 0.5799 - val_accuracy: 0.7231
# Epoch 5/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5268 - accuracy: 0.7439 - val_loss: 0.5623 - val_accuracy: 0.7538
# Epoch 6/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5075 - accuracy: 0.7785 - val_loss: 0.5460 - val_accuracy: 0.7538
# Epoch 7/100
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'])
plt.show()
